# %% [markdown]
# 1. Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.
#
# 2. Apply a distortion correction to raw images.
#
# 3. Use color transforms, gradients, etc., to create a thresholded binary image.
#
# 4. Apply a perspective transform to rectify binary image ("birds-eye view").
#
# 5. Detect lane pixels and fit to find the lane boundary.
#
# 6. Determine the curvature of the lane and vehicle position with respect to center.
#
# 7. Warp the detected lane boundaries back onto the original image.
#
# 8. Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.

# %% [markdown]
# # 1. Computing camera callibration matrix and distortion coeffiecents (function returns matrix callibration matrix and distortion coefficients)

# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
# %matplotlib inline

def get_img_points_and_obj_points(calibration_images_folder):
    objp = np.zeros((9*6,3), np.float32)
    objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

    imgpoints = []
    objpoints = []

    images = glob.glob(calibration_images_folder)

    for i in images:
        img = mpimg.imread(i)

        # convert image to grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        ret, corners = cv2.findChessboardCorners(gray, (9,6), None)

        if ret == True:
            #print(corners)
            imgpoints.append(corners)
            objpoints.append(objp)
            #print(objp.shape)
            #print(corners.shape)
           
            cv2.drawChessboardCorners(img, (9,6), corners, ret)
            #plt.imshow(img)
        
    return imgpoints, objpoints, gray.shape[::-1]

def calibrate_camera(calibration_images_folder):
        imgpoints, objpoints, img_shape = get_img_points_and_obj_points(calibration_images_folder)
        ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints,imgpoints, img_shape, None, None)
        return mtx, dist

mtx, dist = calibrate_camera('camera_cal/calibration*.jpg')

# %% [markdown]
# # 2. Apply A Distortion to Raw Images

# %%
images = glob.glob('test_images/test*.jpg')
num_images = len(images)

test_image = 'test_images/test3.jpg'

undistorted = cv2.undistort(mpimg.imread(test_image),mtx, dist, None, mtx)
#cv2.imwrite('output_images/distortion_correction.jpg',undistorted)
plt.subplot(1,2,1)
plt.imshow(undistorted)
plt.subplot(1,2,2)
plt.imshow(mpimg.imread(test_image))

# %% [markdown]
# # 3. Create a Threshold Binary Image

# %%
def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    `vertices` should be a numpy array of integer points.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

# %%
def create_thresholded_binary_image(img, sobel_thresh_min=20, sobel_thresh_max=30, s_thresh_min=140,s_thresh_max=255):
    # get s channel
    hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
    s_channel = hls[:,:,2]
    
    # get grayscale image
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # get derivatives in x direction for grayscale image
    sobelx = cv2.Sobel(gray, cv2.CV_64F,1,0)
    abs_sobelx = np.absolute(sobelx)
    scaled_sobel = np.uint8(255*abs_sobelx/np.max(abs_sobelx))
    
    # create binary based on gradient thresholds
    sobel_binary = np.zeros_like(scaled_sobel)
    sobel_binary[(scaled_sobel >= sobel_thresh_min) & (scaled_sobel <= sobel_thresh_max)] = 1
    
    # create binary based on s channel thresholds
    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= s_thresh_min) & (s_channel <= s_thresh_max)] = 1
    
    color_binary = np.dstack((np.zeros_like(s_binary),s_binary,sobel_binary)) * 255
    
    combined_binary = np.zeros_like(s_binary)
    combined_binary[(s_binary == 1) | (sobel_binary == 1)] = 1
    #lower_half_combined_binary = combined_binary[int((combined_binary.shape[0])/2):, :]
    
    #vertices = np.array([[(imshape[1]*0.6/3,imshape[0]),((imshape[1]*1)/3, (imshape[0]*1.25)/2), ((imshape[1]*2)/3, (imshape[0]*1.25)/2), ((imshape[1]*2.4)/3,imshape[0])]],dtype=np.int32) 
    #cropped_binary = region_of_interest(combined_binary,vertices)
    
    return combined_binary

i = create_thresholded_binary_image(undistorted)
#imshape = undistorted.shape
#vertices = np.array([[(imshape[1]*0.5/3,imshape[0]),((imshape[1]*1)/3, (imshape[0]*1.1)/2), ((imshape[1]*2)/3, (imshape[0]*1.1)/2), ((imshape[1]*2.5)/3,imshape[0])]],dtype=np.int32) 
#j = region_of_interest(i,vertices)
plt.subplot(1,2,1)
plt.imshow(i)
plt.subplot(1,2,2)
plt.imshow(undistorted)

# %% [markdown]
# # 4. Apply Perspective Transform

# %%
img = mpimg.imread("test_images/straight_lines2.jpg") 
imshape = img.shape
img_size = (img.shape[1],img.shape[0])

src = np.float32([[690, 450],[1042,675],[275,675],[590,450]])
dst = np.float32([[img_size[0]-350,10],[img_size[0]-350,(img_size[1]-10)], [350,img_size[1]-10], [350,10]])

M = cv2.getPerspectiveTransform(src,dst)
Minv = cv2.getPerspectiveTransform(dst,src)

warped_image = cv2.warpPerspective(img,M,img_size, flags=cv2.INTER_LINEAR)
warped_binary = cv2.warpPerspective(i,M,img_size, flags=cv2.INTER_LINEAR)
#vertices = np.array([[(imshape[1]*0.4/3,imshape[0]),((imshape[1]*0.4)/3, 0), ((imshape[1]*2.6)/3, 0), ((imshape[1]*2.6)/3,imshape[0])]],dtype=np.int32) 
#cropped_binary = region_of_interest(warped_binary,vertices)

plt.subplot(1,2,1)
plt.imshow(warped_binary)
plt.subplot(1,2,2)
plt.imshow(warped_image)

# %%
def apply_perspective_transform(image,final_image_size,transformation_matrix):
    imshape = image.shape
    img_size = (imshape[1],imshape[0])
    birds_eye_image = cv2.warpPerspective(image, transformation_matrix, final_image_size,flags=cv2.INTER_LINEAR)
    vertices = np.array([[(imshape[1]*0.4/3,imshape[0]),((imshape[1]*0.4)/3, 0), ((imshape[1]*2.6)/3, 0), ((imshape[1]*2.6)/3,imshape[0])]],dtype=np.int32) 
    cropped_birds_eye_image = region_of_interest(birds_eye_image,vertices)
    return cropped_birds_eye_image

# %%
def draw_lane_boundaries(binary_image):
    histogram = np.sum(binary_image,0)
    midpoint = np.int(histogram.shape[0]//2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint

    out_img = np.dstack((binary_image,binary_image,binary_image))

    nwindows = 9
    margin = 100
    minpix = 50
    window_height = np.int(binary_image.shape[0]//nwindows)
    nonzero = binary_image.nonzero()
    nonzerox = np.array(nonzero[1])
    nonzeroy = np.array(nonzero[0])


    leftx_current = leftx_base
    rightx_current = rightx_base

    left_lane_inds = []
    right_lane_inds = []

    for window in range(nwindows):
        win_y_low = binary_image.shape[0] - (window+1)*window_height
        win_y_high = binary_image.shape[0] - window * window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
    
        cv2.rectangle(out_img, (win_xleft_low,win_y_low), (win_xleft_high, win_y_high), (0,255,0), 2)
        cv2.rectangle(out_img, (win_xright_low,win_y_low), (win_xright_high,win_y_high), (0,255,0),2)
    
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) &
                     (nonzerox >= win_xleft_low) & (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
                (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]

        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
    
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

    left_lane_inds = np.concatenate(left_lane_inds)
    right_lane_inds = np.concatenate(right_lane_inds)
    #except ValueError:
    #    pass


    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds]
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]
    #print(leftx)
    left_fit = np.polyfit(lefty,leftx,2)
    right_fit = np.polyfit(righty, rightx,2)

    ploty = np.linspace(0, binary_image.shape[0]-1, binary_image.shape[0])
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]

    out_img[lefty, leftx] = [255,0,0]
    out_img[righty,rightx] = [0,0,255]

    return ploty, left_fitx, right_fitx, out_img, left_fit, right_fit

p, lf, rf, a, b, c = draw_lane_boundaries(warped_binary)
plt.plot(lf,p,color='red')
plt.plot(rf,p,color='red')
plt.imshow(a)
#plt.imshow(warped_binary)

# %%
def find_lane_curvature(ploty, left_fit, right_fit):
    y_eval = np.max(ploty)
    left_curverad = ((1 + (2*left_fit[0]*y_eval + left_fit[1])**2)**(3/2))/np.absolute(2*left_fit[0])
    right_curverad = ((1 + (2*right_fit[0]*y_eval + right_fit[1])**2)**(3/2))/np.absolute(2*right_fit[0])
    
    return left_curverad, right_curverad

def find_car_position(ploty,left_fit,right_fit,image):
    max_y = np.argmax(ploty)
    left_point = left_fit[max_y]
    right_point = right_fit[max_y]
    mid_point = (right_point - left_point) // 2
    image_center = image.shape[1]//2
    return mid_point - image_center


a,b = find_lane_curvature(p, lf, rf)
mid_point = find_car_position(p,lf,rf, warped_image)
print(mid_point)
# Out:
# -350.0

# %%
def draw_lanes_on_original_image(left_lane_xs,right_lane_xs,y_axis,birds_eye_image,original_image):
    left_lane_points = list(zip(left_lane_xs,y_axis))
    left_lane_points = [np.array([[i,j] for i,j in left_lane_points], np.int32)]
    right_lane_points = list(zip(right_lane_xs,y_axis))
    right_lane_points = [np.array([[i,j] for i,j in right_lane_points], np.int32 )]
    
    birds_eye_zeros = np.zeros_like(birds_eye_image)
    three_d_birds_eye_zeros = np.zeros_like(original_image)

    cv2.polylines(birds_eye_zeros,left_lane_points,False,(255,0,0),thickness=20)
    cv2.polylines(birds_eye_zeros, right_lane_points, False, (255,0,0),thickness=20)
    three_d_birds_eye_zeros[:,:,0] = birds_eye_zeros
    lanes_in_original_perspective = apply_perspective_transform(three_d_birds_eye_zeros,
                                                               (original_image.shape[1],original_image.shape[0]),
                                                                Minv)
    #cv2.addWeighted(warped3,0.9,final_warp_zeros,0.5,0)
    image_with_lanes = cv2.addWeighted(original_image,0.6,lanes_in_original_perspective,1,0)
    return image_with_lanes

# %%
#new_warped = cv2.warpPerspective(final_warp_zeros,Minv,img_size, flags=cv2.INTER_LINEAR)
#f = cv2.addWeighted(undistorted,0.6,new_warped,1,0)

#plt.imshow(f)

# %%
#1. Undistort image
image = mpimg.imread('test_images/test4.jpg')
def process_image(image):
    undistorted_image = cv2.undistort(image,mtx, dist, None, mtx)

    undistorted_image_size = (undistorted_image.shape[1],undistorted_image.shape[0])

    undistorted_binary_image = create_thresholded_binary_image(undistorted_image)

    birds_eye_undistorted_binary_image = apply_perspective_transform(undistorted_binary_image,
                                                                    undistorted_image_size,M)

    y_axis, left_lane_x, right_lane_x, raw_output, left_fit, right_fit = draw_lane_boundaries(birds_eye_undistorted_binary_image)

    lanes_on_original_image = draw_lanes_on_original_image(left_lane_x,
                                                           right_lane_x,
                                                           y_axis,
                                                           birds_eye_undistorted_binary_image,
                                                           undistorted_image)

    left_lane_curvature, right_lane_curvature = find_lane_curvature(y_axis,left_fit, right_fit)

    car_position = find_car_position(y_axis,left_lane_x,right_lane_x,undistorted_image)

    print("Left lane curvature is %s, and right lane curvature is %s" % (str(left_lane_curvature), str(right_lane_curvature)) )

    print("Car position is %f from the center of the road" % car_position)
    #cv2.imwrite('output_images/test1.jpg',lanes_on_original_image)
    #plt.imshow(lanes_on_original_image)
    return lanes_on_original_image

l = process_image(image)
plt.imshow(l)
# Out:
# Left lane curvature is 2815.18234271, and right lane curvature is 1822.83872319
# Car position is -351.000000 from the center of the road

# %%
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
white_output = 'vinal_video.mp4'

clip = VideoFileClip("../CarND-Advanced-Lane-Lines/project_video.mp4")
processed_clip = clip.fl_image(process_image) #NOTE: this function expects color images!!
# %time processed_clip.write_videofile(white_output, audio=False)
# Out:
# Left lane curvature is 1371.51362681, and right lane curvature is 1350.86843938
# Car position is -348.000000 from the center of the road
# [MoviePy] >>>> Building video vinal_video.mp4
# [MoviePy] Writing video vinal_video.mp4
#   0%|          | 1/1261 [00:00<04:53,  4.29it/s]
# Left lane curvature is 1371.51362681, and right lane curvature is 1350.86843938
# Car position is -348.000000 from the center of the road
#   0%|          | 2/1261 [00:00<04:53,  4.29it/s]
# Left lane curvature is 1355.06620552, and right lane curvature is 2138.5454096
# Car position is -346.000000 from the center of the road
#   0%|          | 3/1261 [00:00<04:43,  4.44it/s]
# Left lane curvature is 1374.57556564, and right lane curvature is 3180.22679559
# Car position is -345.000000 from the center of the road
# Left lane curvature is 1337.48613226, and right lane curvature is 2481.32716468
# Car position is -346.000000 from the center of the road
#   0%|          | 5/1261 [00:01<04:26,  4.72it/s]
# Left lane curvature is 1458.70387467, and right lane curvature is 1707.47119726
# Car position is -349.000000 from the center of the road
# Left lane curvature is 1356.14553964, and right lane curvature is 859.314220791
#   0%|          | 6/1261 [00:01<04:23,  4.75it/s]
# Car position is -405.000000 from the center of the road
# Left lane curvature is 1489.0290504, and right lane curvature is 1478.66121658
# Car position is -351.000000 from the center of the road
#   1%|          | 8/1261 [00:01<04:17,  4.86it/s]
# Left lane curvature is 1514.46158385, and right lane curvature is 772.782812508
# Car position is -426.000000 from the center of the road
#   1%|          | 9/1261 [00:01<04:18,  4.85it/s]
# Left lane curvature is 1747.85287976, and right lane curvature is 2036.88263467
# Car position is -352.000000 from the center of the road
# Left lane curvature is 1611.5605005, and right lane curvature is 2546.01959328
# Car position is -346.000000 from the center of the road
#   1%|          | 11/1261 [00:02<04:14,  4.91it/s]
# Left lane curvature is 1742.04309009, and right lane curvature is 6097.56752443
# Car position is -343.000000 from the center of the road
#   1%|          | 12/1261 [00:02<04:17,  4.85it/s]
# Left lane curvature is 1838.22006261, and right lane curvature is 2185.62157814
# Car position is -349.000000 from the center of the road
# Left lane curvature is 1809.46638662, and right lane curvature is 2410.98920949
# Car position is -348.000000 from the center of the road
#   1%|          | 14/1261 [00:02<04:15,  4.89it/s]
# Left lane curvature is 1888.13557811, and right lane curvature is 1184.81360897
# Car position is -355.000000 from the center of the road
#   1%|▏         | 16/1261 [00:03<04:08,  5.01it/s]
# Left lane curvature is 1686.84585127, and right lane curvature is 3213.0747386
# Car position is -348.000000 from the center of the road
#   3%|▎         | 40/1261 [00:07<03:46,  5.39it/s]
# Left lane curvature is 1073.13102095, and right lane curvature is 1691.97383257
# Car position is -347.000000 from the center of the road
# Left lane curvature is 1091.76547198, and right lane curvature is 822.345661334
# Car position is -356.000000 from the center of the road
#   3%|▎         | 42/1261 [00:08<03:50,  5.29it/s]
# Left lane curvature is 1144.60774482, and right lane curvature is 1259.37511171
# Car position is -351.000000 from the center of the road
# Left lane curvature is 1155.20419516, and right lane curvature is 1416.4265627
# Car position is -351.000000 from the center of the road
#   3%|▎         | 43/1261 [00:08<05:11,  3.91it/s]
# Left lane curvature is 1180.52848229, and right lane curvature is 1154.36622598
# Car position is -352.000000 from the center of the road
#   3%|▎         | 44/1261 [00:08<05:11,  3.91it/s]
# Left lane curvature is 1228.69992945, and right lane curvature is 952.891833122
# Car position is -490.000000 from the center of the road
#   4%|▎         | 45/1261 [00:09<05:15,  3.85it/s]
# Left lane curvature is 1288.93977353, and right lane curvature is 1170.56664068
# Car position is -521.000000 from the center of the road
#   4%|▎         | 46/1261 [00:09<05:15,  3.85it/s]
# Left lane curvature is 1379.30102552, and right lane curvature is 1018.84307341
# Car position is -498.000000 from the center of the road
#   4%|▎         | 47/1261 [00:09<05:08,  3.94it/s]
# Left lane curvature is 1322.42767658, and right lane curvature is 901.274733684
# Car position is -468.000000 from the center of the road
#   4%|▍         | 48/1261 [00:09<05:10,  3.91it/s]
# Left lane curvature is 1360.44682011, and right lane curvature is 1031.11923886
# Car position is -423.000000 from the center of the road
#   4%|▍         | 49/1261 [00:10<05:11,  3.89it/s]
# Left lane curvature is 1418.00423453, and right lane curvature is 1855.28979991
# Car position is -345.000000 from the center of the road
#   4%|▍         | 50/1261 [00:10<05:04,  3.97it/s]
# Left lane curvature is 1520.62111426, and right lane curvature is 794.381042198
# Car position is -361.000000 from the center of the road
#   4%|▍         | 51/1261 [00:10<05:09,  3.91it/s]
# Left lane curvature is 1587.05523533, and right lane curvature is 1431.46438242
# Car position is -352.000000 from the center of the road
#   4%|▍         | 52/1261 [00:10<05:00,  4.03it/s]
# Left lane curvature is 1643.70651718, and right lane curvature is 2017.70238596
# Car position is -349.000000 from the center of the road
#   4%|▍         | 53/1261 [00:11<05:12,  3.86it/s]
# Left lane curvature is 1598.39233217, and right lane curvature is 1853.61361225
# Car position is -350.000000 from the center of the road
#   4%|▍         | 54/1261 [00:11<05:02,  3.98it/s]
# Left lane curvature is 1593.83525034, and right lane curvature is 1140.97922536
# Car position is -353.000000 from the center of the road
#   4%|▍         | 55/1261 [00:11<05:01,  4.00it/s]
# Left lane curvature is 1693.47133936, and right lane curvature is 1508.58571017
# Car position is -352.000000 from the center of the road
#   4%|▍         | 56/1261 [00:11<05:06,  3.93it/s]
# Left lane curvature is 1780.19064006, and right lane curvature is 1177.40289045
# Car position is -353.000000 from the center of the road
#   5%|▍         | 57/1261 [00:12<05:16,  3.80it/s]
# Left lane curvature is 1661.12347698, and right lane curvature is 779.154892559
# Car position is -415.000000 from the center of the road
#   5%|▍         | 58/1261 [00:12<05:14,  3.83it/s]
# Left lane curvature is 1743.05583236, and right lane curvature is 918.285459892
# Car position is -482.000000 from the center of the road
#   5%|▍         | 59/1261 [00:12<05:16,  3.80it/s]
# Left lane curvature is 1610.85235272, and right lane curvature is 816.218234704
# Car position is -419.000000 from the center of the road
#   5%|▍         | 60/1261 [00:13<05:14,  3.81it/s]
# Left lane curvature is 1593.34542418, and right lane curvature is 1077.46982717
# Car position is -519.000000 from the center of the road
#   5%|▍         | 61/1261 [00:13<05:10,  3.86it/s]
# Left lane curvature is 1783.81138758, and right lane curvature is 965.557660921
# Car position is -503.000000 from the center of the road
#   5%|▍         | 62/1261 [00:13<05:12,  3.84it/s]
# Left lane curvature is 1929.28312797, and right lane curvature is 982.174164261
# Car position is -517.000000 from the center of the road
#   5%|▍         | 63/1261 [00:13<05:09,  3.88it/s]
# Left lane curvature is 1939.24304956, and right lane curvature is 759.36323923
# Car position is -419.000000 from the center of the road
#   5%|▌         | 64/1261 [00:14<05:06,  3.90it/s]
# Left lane curvature is 1662.54183656, and right lane curvature is 1091.6690233
# Car position is -357.000000 from the center of the road
#   5%|▌         | 65/1261 [00:14<05:07,  3.89it/s]
# Left lane curvature is 1832.25763284, and right lane curvature is 1071.00264118
# Car position is -356.000000 from the center of the road
#   5%|▌         | 66/1261 [00:14<05:05,  3.91it/s]
# Left lane curvature is 2061.93200322, and right lane curvature is 1378.00910141
# Car position is -354.000000 from the center of the road
#   5%|▌         | 67/1261 [00:14<05:06,  3.89it/s]
# Left lane curvature is 1867.70910212, and right lane curvature is 1818.40208903
# Car position is -353.000000 from the center of the road
#   5%|▌         | 68/1261 [00:15<05:10,  3.84it/s]
# Left lane curvature is 1884.76522747, and right lane curvature is 2418.95230452
# Car position is -351.000000 from the center of the road
#   5%|▌         | 69/1261 [00:15<05:11,  3.83it/s]
# Left lane curvature is 1614.18870664, and right lane curvature is 916.723298886
# Car position is -386.000000 from the center of the road
#   6%|▌         | 70/1261 [00:15<05:06,  3.89it/s]
# Left lane curvature is 1853.16806928, and right lane curvature is 935.322284728
# Car position is -480.000000 from the center of the road
#   6%|▌         | 71/1261 [00:15<05:14,  3.79it/s]
# Left lane curvature is 1681.72442482, and right lane curvature is 833.144210449
# Car position is -444.000000 from the center of the road
#   6%|▌         | 72/1261 [00:16<05:11,  3.82it/s]
# Left lane curvature is 1813.50112305, and right lane curvature is 2121.52606238
# Car position is -350.000000 from the center of the road
#   6%|▌         | 73/1261 [00:16<05:10,  3.83it/s]
# Left lane curvature is 1747.81175785, and right lane curvature is 1357.58089469
# Car position is -356.000000 from the center of the road
#   6%|▌         | 74/1261 [00:16<05:12,  3.80it/s]
# Left lane curvature is 1798.63779863, and right lane curvature is 1003.43271358
# Car position is -498.000000 from the center of the road
#   6%|▌         | 75/1261 [00:16<05:11,  3.81it/s]
# Left lane curvature is 2049.36482159, and right lane curvature is 1521.30709531
# Car position is -354.000000 from the center of the road
#   6%|▌         | 76/1261 [00:17<05:11,  3.81it/s]
# Left lane curvature is 2242.5527416, and right lane curvature is 1455.75107917
# Car position is -356.000000 from the center of the road
#   6%|▌         | 77/1261 [00:17<05:07,  3.85it/s]
# Left lane curvature is 2447.91470701, and right lane curvature is 1423.57406388
# Car position is -354.000000 from the center of the road
#   6%|▌         | 78/1261 [00:17<05:05,  3.87it/s]
# Left lane curvature is 2517.44913704, and right lane curvature is 1629.85830811
# Car position is -353.000000 from the center of the road
#   6%|▋         | 79/1261 [00:18<06:04,  3.25it/s]
# Left lane curvature is 2564.78162215, and right lane curvature is 1350.27503977
# Car position is -352.000000 from the center of the road
#   6%|▋         | 80/1261 [00:18<06:05,  3.23it/s]
# Left lane curvature is 2433.5457853, and right lane curvature is 1415.07886399
# Car position is -351.000000 from the center of the road
#   6%|▋         | 81/1261 [00:18<05:39,  3.48it/s]
# Left lane curvature is 2245.72893238, and right lane curvature is 1182.17459598
# Car position is -351.000000 from the center of the road
#   7%|▋         | 82/1261 [00:18<05:30,  3.57it/s]
# Left lane curvature is 2107.52164755, and right lane curvature is 855.230027859
# Car position is -431.000000 from the center of the road
#   7%|▋         | 83/1261 [00:19<05:21,  3.66it/s]
# Left lane curvature is 2132.59230938, and right lane curvature is 1217.63653244
# Car position is -353.000000 from the center of the road
#   7%|▋         | 84/1261 [00:19<05:18,  3.70it/s]
# Left lane curvature is 2308.02082177, and right lane curvature is 1190.54932149
# Car position is -351.000000 from the center of the road
#   7%|▋         | 85/1261 [00:19<05:05,  3.85it/s]
# Left lane curvature is 2108.73014534, and right lane curvature is 1241.85060767
# Car position is -349.000000 from the center of the road
#   7%|▋         | 86/1261 [00:19<05:11,  3.78it/s]
# Left lane curvature is 1915.25151809, and right lane curvature is 1955.01446616
# Car position is -341.000000 from the center of the road
#   7%|▋         | 87/1261 [00:20<05:10,  3.78it/s]
# Left lane curvature is 1599.61545088, and right lane curvature is 1178.22351817
# Car position is -347.000000 from the center of the road
#   7%|▋         | 88/1261 [00:20<05:08,  3.80it/s]
# Left lane curvature is 1514.74064404, and right lane curvature is 1667.64360279
# Car position is -345.000000 from the center of the road
#   7%|▋         | 89/1261 [00:20<05:10,  3.78it/s]
# Left lane curvature is 1382.74367491, and right lane curvature is 1356.94496374
# Car position is -346.000000 from the center of the road
#   7%|▋         | 90/1261 [00:21<05:11,  3.76it/s]
# Left lane curvature is 1276.37110691, and right lane curvature is 1063.78858837
# Car position is -350.000000 from the center of the road
#   7%|▋         | 91/1261 [00:21<05:07,  3.81it/s]
# Left lane curvature is 1361.68362538, and right lane curvature is 1283.72085077
# Car position is -348.000000 from the center of the road
#   7%|▋         | 92/1261 [00:21<05:10,  3.77it/s]
# Left lane curvature is 1393.11223452, and right lane curvature is 1279.45441386
# Car position is -348.000000 from the center of the road
#   7%|▋         | 93/1261 [00:21<05:08,  3.79it/s]
# Left lane curvature is 1339.76209697, and right lane curvature is 1455.03170493
# Car position is -349.000000 from the center of the road
#   7%|▋         | 94/1261 [00:22<05:07,  3.79it/s]
# Left lane curvature is 1296.70668041, and right lane curvature is 1664.29733835
# Car position is -348.000000 from the center of the road
#   8%|▊         | 95/1261 [00:22<05:04,  3.82it/s]
# Left lane curvature is 1388.44647296, and right lane curvature is 854.995367593
# Car position is -423.000000 from the center of the road
#   8%|▊         | 96/1261 [00:22<05:04,  3.83it/s]
# Left lane curvature is 1342.87191459, and right lane curvature is 1178.36294623
# Car position is -355.000000 from the center of the road
#   8%|▊         | 97/1261 [00:22<05:03,  3.83it/s]
# Left lane curvature is 1376.50050325, and right lane curvature is 877.668964158
# Car position is -427.000000 from the center of the road
#   8%|▊         | 98/1261 [00:23<05:07,  3.79it/s]
# Left lane curvature is 1386.83737171, and right lane curvature is 1123.54383725
# Car position is -357.000000 from the center of the road
#   8%|▊         | 99/1261 [00:23<05:06,  3.79it/s]
# Left lane curvature is 1427.50385601, and right lane curvature is 1111.29304042
# Car position is -358.000000 from the center of the road
#   8%|▊         | 100/1261 [00:23<05:07,  3.77it/s]
# Left lane curvature is 1400.68366225, and right lane curvature is 1375.81144456
# Car position is -354.000000 from the center of the road
#   8%|▊         | 101/1261 [00:23<05:10,  3.74it/s]
# Left lane curvature is 1309.78327305, and right lane curvature is 1492.76007578
# Car position is -352.000000 from the center of the road
#   8%|▊         | 102/1261 [00:24<05:04,  3.81it/s]
# Left lane curvature is 1265.41925881, and right lane curvature is 1222.36849611
# Car position is -356.000000 from the center of the road
#   8%|▊         | 103/1261 [00:24<05:03,  3.82it/s]
# Left lane curvature is 1354.58964952, and right lane curvature is 1333.70655189
# Car position is -354.000000 from the center of the road
#   8%|▊         | 104/1261 [00:24<05:03,  3.81it/s]
# Left lane curvature is 1421.05194612, and right lane curvature is 1222.7093084
# Car position is -356.000000 from the center of the road
#   8%|▊         | 105/1261 [00:24<05:01,  3.84it/s]
# Left lane curvature is 1480.11108618, and right lane curvature is 1017.30894225
# Car position is -355.000000 from the center of the road
#   8%|▊         | 106/1261 [00:25<04:56,  3.89it/s]
# Left lane curvature is 1461.59771198, and right lane curvature is 1061.14054759
# Car position is -353.000000 from the center of the road
#   8%|▊         | 107/1261 [00:25<05:01,  3.83it/s]
# Left lane curvature is 1470.14824496, and right lane curvature is 840.501039552
# Car position is -431.000000 from the center of the road
#   9%|▊         | 108/1261 [00:25<05:02,  3.81it/s]
# Left lane curvature is 1333.6384963, and right lane curvature is 985.118587909
# Car position is -356.000000 from the center of the road
#   9%|▊         | 109/1261 [00:25<04:51,  3.95it/s]
# Left lane curvature is 1297.56980561, and right lane curvature is 1084.0864276
# Car position is -356.000000 from the center of the road
#   9%|▊         | 110/1261 [00:26<04:55,  3.90it/s]
# Left lane curvature is 1240.49118714, and right lane curvature is 1244.68106833
# Car position is -351.000000 from the center of the road
#   9%|▉         | 111/1261 [00:26<04:45,  4.03it/s]
# Left lane curvature is 1181.35862925, and right lane curvature is 2793.05160201
# Car position is -341.000000 from the center of the road
#   9%|▉         | 112/1261 [00:26<04:46,  4.01it/s]
# Left lane curvature is 1252.4722736, and right lane curvature is 1443.64604028
# Car position is -348.000000 from the center of the road
#   9%|▉         | 113/1261 [00:26<04:51,  3.94it/s]
# Left lane curvature is 893.853437911, and right lane curvature is 1025.37467064
# Car position is -505.000000 from the center of the road
#  15%|█▍        | 187/1261 [00:45<04:32,  3.94it/s]
# Left lane curvature is 870.996034981, and right lane curvature is 1450.64048143
# Car position is -599.000000 from the center of the road
#  15%|█▍        | 188/1261 [00:46<04:42,  3.80it/s]
# Left lane curvature is 924.960562257, and right lane curvature is 1289.1057859
# Car position is -577.000000 from the center of the road
#  15%|█▍        | 189/1261 [00:46<04:38,  3.85it/s]
# Left lane curvature is 938.189148545, and right lane curvature is 1288.19119246
# Car position is -342.000000 from the center of the road
#  15%|█▌        | 190/1261 [00:46<04:36,  3.87it/s]
# Left lane curvature is 939.896954532, and right lane curvature is 1155.59062033
# Car position is -557.000000 from the center of the road
#  15%|█▌        | 191/1261 [00:46<04:40,  3.81it/s]
# Left lane curvature is 939.122378792, and right lane curvature is 991.955139521
# Car position is -348.000000 from the center of the road
#  15%|█▌        | 192/1261 [00:47<04:41,  3.80it/s]
# Left lane curvature is 940.131343491, and right lane curvature is 1508.97274541
# Car position is -345.000000 from the center of the road
#  15%|█▌        | 193/1261 [00:47<04:41,  3.80it/s]
# Left lane curvature is 944.20114683, and right lane curvature is 924.555671819
# Car position is -512.000000 from the center of the road
#  15%|█▌        | 194/1261 [00:47<04:42,  3.78it/s]
# Left lane curvature is 988.413672771, and right lane curvature is 870.072043426
# Car position is -502.000000 from the center of the road
#  15%|█▌        | 195/1261 [00:47<04:36,  3.85it/s]
# Left lane curvature is 1045.61749723, and right lane curvature is 1039.46940974
# Car position is -540.000000 from the center of the road
#  16%|█▌        | 196/1261 [00:48<04:35,  3.87it/s]
# Left lane curvature is 1170.29567025, and right lane curvature is 905.356357466
# Car position is -491.000000 from the center of the road
#  16%|█▌        | 197/1261 [00:48<04:38,  3.83it/s]
# Left lane curvature is 1296.44722652, and right lane curvature is 926.216461029
# Car position is -456.000000 from the center of the road
#  16%|█▌        | 198/1261 [00:48<04:37,  3.83it/s]
# Left lane curvature is 1469.7726271, and right lane curvature is 1632.78214662
# Car position is -345.000000 from the center of the road
#  16%|█▌        | 199/1261 [00:49<04:34,  3.87it/s]
# Left lane curvature is 1593.74610708, and right lane curvature is 1834.32597054
# Car position is -342.000000 from the center of the road
#  16%|█▌        | 200/1261 [00:49<04:37,  3.83it/s]
# Left lane curvature is 1605.62916599, and right lane curvature is 1625.66517552
# Car position is -343.000000 from the center of the road
#  16%|█▌        | 201/1261 [00:49<04:35,  3.85it/s]
# Left lane curvature is 1566.83827998, and right lane curvature is 1978.93862199
# Car position is -340.000000 from the center of the road
#  16%|█▌        | 202/1261 [00:49<04:31,  3.90it/s]
# Left lane curvature is 1541.78719375, and right lane curvature is 1834.46048806
# Car position is -341.000000 from the center of the road
#  16%|█▌        | 203/1261 [00:50<04:32,  3.89it/s]
# Left lane curvature is 1516.34958263, and right lane curvature is 2154.57616302
# Car position is -340.000000 from the center of the road
#  16%|█▌        | 204/1261 [00:50<04:27,  3.95it/s]
# Left lane curvature is 1397.60372505, and right lane curvature is 1567.42041347
# Car position is -341.000000 from the center of the road
#  16%|█▋        | 205/1261 [00:50<04:27,  3.95it/s]
# Left lane curvature is 1366.04942795, and right lane curvature is 1188.06041003
# Car position is -344.000000 from the center of the road
#  16%|█▋        | 206/1261 [00:50<04:34,  3.85it/s]
# Left lane curvature is 1263.94066524, and right lane curvature is 1144.4733316
# Car position is -344.000000 from the center of the road
#  16%|█▋        | 207/1261 [00:51<04:32,  3.87it/s]
# Left lane curvature is 1182.55560464, and right lane curvature is 1129.33332216
# Car position is -532.000000 from the center of the road
#  16%|█▋        | 208/1261 [00:51<04:31,  3.88it/s]
# Left lane curvature is 1083.98683631, and right lane curvature is 995.391394341
# Car position is -504.000000 from the center of the road
#  17%|█▋        | 209/1261 [00:51<04:35,  3.82it/s]
# Left lane curvature is 1199.14503273, and right lane curvature is 1085.79494554
# Car position is -372.000000 from the center of the road
#  17%|█▋        | 210/1261 [00:51<04:36,  3.81it/s]
# Left lane curvature is 1254.2472485, and right lane curvature is 990.242304355
# Car position is -494.000000 from the center of the road
#  17%|█▋        | 211/1261 [00:52<04:33,  3.84it/s]
# Left lane curvature is 1287.35258546, and right lane curvature is 3301.78896365
# Car position is -337.000000 from the center of the road
#  17%|█▋        | 212/1261 [00:52<04:33,  3.84it/s]
# Left lane curvature is 1213.90099148, and right lane curvature is 1249.49639766
# Car position is -346.000000 from the center of the road
#  17%|█▋        | 213/1261 [00:52<04:31,  3.86it/s]
# Left lane curvature is 1261.2786238, and right lane curvature is 1601.07058088
# Car position is -343.000000 from the center of the road
#  17%|█▋        | 214/1261 [00:52<04:29,  3.89it/s]
# Left lane curvature is 1220.5351651, and right lane curvature is 2559.65642697
# Car position is -342.000000 from the center of the road
#  17%|█▋        | 215/1261 [00:53<04:31,  3.86it/s]
# Left lane curvature is 1259.03299278, and right lane curvature is 1753.57153511
# Car position is -344.000000 from the center of the road
#  17%|█▋        | 216/1261 [00:53<04:43,  3.69it/s]
# Left lane curvature is 1333.67074991, and right lane curvature is 1573.80201815
# Car position is -346.000000 from the center of the road
#  17%|█▋        | 217/1261 [00:53<04:39,  3.73it/s]
# Left lane curvature is 1296.93483478, and right lane curvature is 1417.50092485
# Car position is -347.000000 from the center of the road
#  17%|█▋        | 218/1261 [00:53<04:31,  3.83it/s]
# Left lane curvature is 1343.99744878, and right lane curvature is 1373.05415604
# Car position is -348.000000 from the center of the road
#  17%|█▋        | 219/1261 [00:54<04:30,  3.86it/s]
# Left lane curvature is 1261.19907427, and right lane curvature is 1096.72664722
# Car position is -486.000000 from the center of the road
#  17%|█▋        | 220/1261 [00:54<04:25,  3.93it/s]
# Left lane curvature is 1361.46945749, and right lane curvature is 904.184521797
# Car position is -468.000000 from the center of the road
#  18%|█▊        | 221/1261 [00:54<04:25,  3.92it/s]
# Left lane curvature is 1398.5948385, and right lane curvature is 1382.1005827
# Car position is -355.000000 from the center of the road
#  18%|█▊        | 222/1261 [00:54<04:22,  3.95it/s]
# Left lane curvature is 1482.63882406, and right lane curvature is 2305.32864259
#  21%|██        | 259/1261 [01:04<04:17,  3.89it/s]
# Left lane curvature is 1454.91408545, and right lane curvature is 1094.60422703
# Car position is -510.000000 from the center of the road
#  21%|██        | 260/1261 [01:05<04:23,  3.81it/s]
# Left lane curvature is 1502.60048674, and right lane curvature is 747.203620212
# Car position is -361.000000 from the center of the road
#  21%|██        | 261/1261 [01:05<04:21,  3.82it/s]
# Left lane curvature is 1527.93330827, and right lane curvature is 1116.58640262
# Car position is -353.000000 from the center of the road
# ...
# Car position is -348.000000 from the center of the road
#  93%|█████████▎| 1177/1261 [05:18<00:26,  3.17it/s]
# Left lane curvature is 4109.78176038, and right lane curvature is 2332.74584172
# Car position is -350.000000 from the center of the road
#  93%|█████████▎| 1178/1261 [05:18<00:25,  3.23it/s]
# Left lane curvature is 7776.02544937, and right lane curvature is 1567.47212251
# Car position is -345.000000 from the center of the road
#  93%|█████████▎| 1179/1261 [05:18<00:23,  3.45it/s]
# Left lane curvature is 4230.93518885, and right lane curvature is 1590.05038678
# Car position is -348.000000 from the center of the road
#  94%|█████████▎| 1180/1261 [05:19<00:23,  3.47it/s]
# Left lane curvature is 4659.89383429, and right lane curvature is 3325.63845961
# Car position is -350.000000 from the center of the road
#  94%|█████████▎| 1181/1261 [05:19<00:21,  3.67it/s]
# Left lane curvature is 6603.24466971, and right lane curvature is 1876.62069855
# Car position is -348.000000 from the center of the road
#  94%|█████████▎| 1182/1261 [05:19<00:21,  3.71it/s]
# Left lane curvature is 3765.80332006, and right lane curvature is 2044.39685606
# Car position is -350.000000 from the center of the road
#  94%|█████████▍| 1183/1261 [05:20<00:21,  3.60it/s]
# Left lane curvature is 2764.45157696, and right lane curvature is 3814.87917116
# Car position is -352.000000 from the center of the road
#  94%|█████████▍| 1184/1261 [05:20<00:21,  3.59it/s]
# Left lane curvature is 3129.249458, and right lane curvature is 3046.77361542
# Car position is -350.000000 from the center of the road
#  94%|█████████▍| 1185/1261 [05:20<00:20,  3.77it/s]
# Left lane curvature is 2873.60266267, and right lane curvature is 2084.90043224
# Car position is -351.000000 from the center of the road
#  94%|█████████▍| 1186/1261 [05:20<00:20,  3.71it/s]
# Left lane curvature is 2897.40097208, and right lane curvature is 5773.94742954
# Car position is -359.000000 from the center of the road
#  94%|█████████▍| 1187/1261 [05:21<00:19,  3.82it/s]
# Left lane curvature is 2562.44502002, and right lane curvature is 1196.35346028
# Car position is -344.000000 from the center of the road
#  94%|█████████▍| 1188/1261 [05:21<00:19,  3.74it/s]
# Left lane curvature is 2897.02304279, and right lane curvature is 2604.29537635
# Car position is -353.000000 from the center of the road
#  94%|█████████▍| 1189/1261 [05:21<00:18,  3.88it/s]
# Left lane curvature is 2723.75458179, and right lane curvature is 2361.92229312
# Car position is -350.000000 from the center of the road
#  94%|█████████▍| 1190/1261 [05:21<00:19,  3.73it/s]
# Left lane curvature is 2044.87297761, and right lane curvature is 1741.93158803
# Car position is -351.000000 from the center of the road
#  94%|█████████▍| 1191/1261 [05:22<00:18,  3.85it/s]
# Left lane curvature is 1858.46083718, and right lane curvature is 2244.3243961
# Car position is -359.000000 from the center of the road
#  96%|█████████▌| 1210/1261 [05:27<00:13,  3.78it/s]
# Left lane curvature is 1893.52473963, and right lane curvature is 1697.67792983
# Car position is -356.000000 from the center of the road
#  96%|█████████▌| 1211/1261 [05:27<00:12,  3.85it/s]
# Left lane curvature is 1993.48398779, and right lane curvature is 2558.73011625
# Car position is -358.000000 from the center of the road
#  96%|█████████▌| 1212/1261 [05:27<00:12,  3.85it/s]
# Left lane curvature is 1898.84633199, and right lane curvature is 4057.40427024
# Car position is -360.000000 from the center of the road
#  96%|█████████▌| 1213/1261 [05:27<00:12,  3.73it/s]
# Left lane curvature is 2298.4361269, and right lane curvature is 2390.12775952
# Car position is -355.000000 from the center of the road
#  96%|█████████▋| 1214/1261 [05:28<00:12,  3.65it/s]
# Left lane curvature is 2455.50084716, and right lane curvature is 2239.50638654
# Car position is -354.000000 from the center of the road
#  96%|█████████▋| 1215/1261 [05:28<00:12,  3.81it/s]
# Left lane curvature is 2982.45674005, and right lane curvature is 2315.51248564
# Car position is -353.000000 from the center of the road
#  96%|█████████▋| 1216/1261 [05:28<00:12,  3.72it/s]
# Left lane curvature is 2446.72943049, and right lane curvature is 1409.29025579
# Car position is -351.000000 from the center of the road
#  97%|█████████▋| 1217/1261 [05:29<00:11,  3.69it/s]
# Left lane curvature is 3024.52333705, and right lane curvature is 3681.00257719
# Car position is -352.000000 from the center of the road
#  97%|█████████▋| 1218/1261 [05:29<00:11,  3.84it/s]
# Left lane curvature is 3126.41478441, and right lane curvature is 3779.68214707
# Car position is -351.000000 from the center of the road
#  97%|█████████▋| 1219/1261 [05:29<00:11,  3.77it/s]
# Left lane curvature is 3252.75410563, and right lane curvature is 2330.4147901
# Car position is -351.000000 from the center of the road
#  97%|█████████▋| 1220/1261 [05:29<00:10,  3.81it/s]
# Left lane curvature is 2894.41570552, and right lane curvature is 3203.41860277
# Car position is -354.000000 from the center of the road
#  97%|█████████▋| 1221/1261 [05:30<00:10,  3.75it/s]
# Left lane curvature is 3918.48231638, and right lane curvature is 2291.17975074
# Car position is -349.000000 from the center of the road
#  97%|█████████▋| 1222/1261 [05:30<00:10,  3.89it/s]
# Left lane curvature is 2792.7342917, and right lane curvature is 1438.24746517
# Car position is -347.000000 from the center of the road
#  97%|█████████▋| 1223/1261 [05:30<00:10,  3.75it/s]
# Left lane curvature is 3197.61316293, and right lane curvature is 2461.41924869
# Car position is -353.000000 from the center of the road
#  97%|█████████▋| 1224/1261 [05:30<00:09,  3.87it/s]
# Left lane curvature is 3737.89052738, and right lane curvature is 2479.11642892
# Car position is -353.000000 from the center of the road
#  97%|█████████▋| 1225/1261 [05:31<00:09,  3.77it/s]
# Left lane curvature is 4127.1432242, and right lane curvature is 3139.10007937
# Car position is -354.000000 from the center of the road
#  97%|█████████▋| 1226/1261 [05:31<00:09,  3.85it/s]
# Left lane curvature is 4138.81011813, and right lane curvature is 2283.88175898
# Car position is -352.000000 from the center of the road
#  97%|█████████▋| 1227/1261 [05:31<00:09,  3.74it/s]
# Left lane curvature is 5145.65833022, and right lane curvature is 3739.19464342
# Car position is -350.000000 from the center of the road
#  97%|█████████▋| 1228/1261 [05:31<00:08,  3.86it/s]
# Left lane curvature is 3963.76185157, and right lane curvature is 2557.06306536
# Car position is -350.000000 from the center of the road
#  97%|█████████▋| 1229/1261 [05:32<00:08,  3.75it/s]
# Left lane curvature is 4832.01696348, and right lane curvature is 1795.79537965
# Car position is -348.000000 from the center of the road
#  98%|█████████▊| 1230/1261 [05:32<00:08,  3.85it/s]
# Left lane curvature is 7145.27035299, and right lane curvature is 3958.80828392
# Car position is -348.000000 from the center of the road
#  98%|█████████▊| 1231/1261 [05:32<00:07,  3.80it/s]
# Left lane curvature is 8217.791284, and right lane curvature is 1994.59136017
# Car position is -347.000000 from the center of the road
#  98%|█████████▊| 1232/1261 [05:32<00:07,  3.85it/s]
# Left lane curvature is 8468.75580136, and right lane curvature is 4464.24249368
# Car position is -352.000000 from the center of the road
#  98%|█████████▊| 1233/1261 [05:33<00:07,  3.78it/s]
# Left lane curvature is 7660.65977055, and right lane curvature is 4592.6356945
# Car position is -354.000000 from the center of the road
#  98%|█████████▊| 1234/1261 [05:33<00:06,  3.89it/s]
# Left lane curvature is 10615.2042748, and right lane curvature is 36404.3981905
# Car position is -358.000000 from the center of the road
#  98%|█████████▊| 1235/1261 [05:33<00:06,  3.79it/s]
# Left lane curvature is 6489.28183918, and right lane curvature is 10860.2143929
# Car position is -358.000000 from the center of the road
#  98%|█████████▊| 1236/1261 [05:34<00:06,  3.86it/s]
# Left lane curvature is 16585.5270929, and right lane curvature is 12298.0159126
# Car position is -354.000000 from the center of the road
#  98%|█████████▊| 1237/1261 [05:34<00:06,  3.78it/s]
# Left lane curvature is 10755.8992556, and right lane curvature is 9274.89286017
# Car position is -353.000000 from the center of the road
#  98%|█████████▊| 1238/1261 [05:34<00:06,  3.80it/s]
# Left lane curvature is 16608.8393141, and right lane curvature is 12229.5980528
# Car position is -350.000000 from the center of the road
#  98%|█████████▊| 1239/1261 [05:34<00:05,  3.71it/s]
# Left lane curvature is 11787.0043086, and right lane curvature is 20360.4076869
# Car position is -351.000000 from the center of the road
#  98%|█████████▊| 1240/1261 [05:35<00:05,  3.84it/s]
# Left lane curvature is 11813.9707401, and right lane curvature is 12560.7952698
# Car position is -350.000000 from the center of the road
#  98%|█████████▊| 1241/1261 [05:35<00:05,  3.75it/s]
# Left lane curvature is 22223.1876382, and right lane curvature is 5466.87976555
# Car position is -349.000000 from the center of the road
#  98%|█████████▊| 1242/1261 [05:35<00:04,  3.85it/s]
# Left lane curvature is 47723.8732677, and right lane curvature is 11278.6625371
# Car position is -351.000000 from the center of the road
#  99%|█████████▊| 1243/1261 [05:35<00:04,  3.77it/s]
# Left lane curvature is 59835.181759, and right lane curvature is 4827.18311072
# Car position is -357.000000 from the center of the road
#  99%|█████████▊| 1244/1261 [05:36<00:04,  3.51it/s]
# Left lane curvature is 9545.32565293, and right lane curvature is 4871.65639757
# Car position is -347.000000 from the center of the road
#  99%|█████████▊| 1245/1261 [05:36<00:04,  3.72it/s]
# Left lane curvature is 44833.5301816, and right lane curvature is 9710.13502011
# Car position is -353.000000 from the center of the road
#  99%|█████████▉| 1246/1261 [05:36<00:04,  3.66it/s]
# Left lane curvature is 11797.4659259, and right lane curvature is 26154.7492564
# Car position is -349.000000 from the center of the road
#  99%|█████████▉| 1247/1261 [05:36<00:03,  3.76it/s]
# Left lane curvature is 6279.64869817, and right lane curvature is 10848.1155612
# Car position is -353.000000 from the center of the road
#  99%|█████████▉| 1248/1261 [05:37<00:03,  3.70it/s]
# Left lane curvature is 14760.4973003, and right lane curvature is 12589.8829455
# Car position is -349.000000 from the center of the road
#  99%|█████████▉| 1249/1261 [05:37<00:03,  3.88it/s]
# Left lane curvature is 6981.12346319, and right lane curvature is 6591.31231022
# Car position is -349.000000 from the center of the road
#  99%|█████████▉| 1250/1261 [05:37<00:02,  3.77it/s]
# Left lane curvature is 6600.07184851, and right lane curvature is 3596.8796683
# Car position is -349.000000 from the center of the road
#  99%|█████████▉| 1251/1261 [05:37<00:02,  3.90it/s]
# Left lane curvature is 8120.44349615, and right lane curvature is 6666.8288918
# Car position is -348.000000 from the center of the road
#  99%|█████████▉| 1252/1261 [05:38<00:02,  3.81it/s]
# Left lane curvature is 11106.0637815, and right lane curvature is 21264.6269266
# Car position is -348.000000 from the center of the road
#  99%|█████████▉| 1253/1261 [05:38<00:02,  3.93it/s]
# Left lane curvature is 20411.4541034, and right lane curvature is 5424.45776587
# Car position is -353.000000 from the center of the road
#  99%|█████████▉| 1254/1261 [05:38<00:01,  3.76it/s]
# Left lane curvature is 20489.5941051, and right lane curvature is 10295.730595
# Car position is -344.000000 from the center of the road
# 100%|█████████▉| 1255/1261 [05:39<00:01,  3.91it/s]
# Left lane curvature is 16298.9475877, and right lane curvature is 6493.67657389
# Car position is -350.000000 from the center of the road
# 100%|█████████▉| 1256/1261 [05:39<00:01,  3.82it/s]
# Left lane curvature is 43337.3827598, and right lane curvature is 7234.86514194
# Car position is -342.000000 from the center of the road
# 100%|█████████▉| 1257/1261 [05:39<00:01,  3.74it/s]
# Left lane curvature is 20614.843784, and right lane curvature is 42246.5932842
# Car position is -345.000000 from the center of the road
# 100%|█████████▉| 1258/1261 [05:39<00:00,  3.86it/s]
# Left lane curvature is 117794.056016, and right lane curvature is 10924.1276243
# Car position is -345.000000 from the center of the road
# 100%|█████████▉| 1259/1261 [05:40<00:00,  3.74it/s]
# Left lane curvature is 61148.1322426, and right lane curvature is 4907.32324057
# Car position is -342.000000 from the center of the road
# 100%|█████████▉| 1260/1261 [05:40<00:00,  3.91it/s]
# Left lane curvature is 21612.5258172, and right lane curvature is 3268.6250849
# Car position is -340.000000 from the center of the road
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: vinal_video.mp4
#
# CPU times: user 3min, sys: 30.2 s, total: 3min 30s
# Wall time: 5min 43s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="<moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f6acb9bfc50>">
# </video>
